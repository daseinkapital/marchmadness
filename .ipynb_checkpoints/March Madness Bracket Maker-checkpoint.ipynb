# %%
from MarchMadness import MarchMadness
import random

# %%
def main():
    march_madness = MarchMadness()
    random.seed()
    march_madness.coin_toss()
    
main()
# Out:
# east :
#
# Round 1
#
# NDS/NCC (16) beats Duke (1)
# UCF (9) beats VCU (8)
# Liberty (12) beats Mississippi St (5)
# Virginia Tech (4) beats Saint Louis (13)
# Belmont (11) beats Maryland (6)
# LSU (3) beats Yale (14)
# Minnesota (10) beats Louisville (7)
# Michigan St (2) beats Bradley (15)
#
# Round 2
#
# UCF (9) beats NDS/NCC (16)
# Liberty (12) beats Virginia Tech (4)
# LSU (3) beats Belmont (11)
# Minnesota (10) beats Michigan St (2)
#
# Round 3
#
# Liberty (12) beats UCF (9)
# Minnesota (10) beats LSU (3)
#
# Round 4
#
# Liberty (12) beats Minnesota (10)
#
#
#
#
# south :
#
# Round 1
#
# Virginia (1) beats Gardner-Webb (16)
# Ole Miss (8) beats Oklahoma (9)
# Oregon (12) beats Wisconsin (5)
# Kansas State (4) beats UC Irvine (13)
# Saint Mary's (11) beats Villanova (6)
# Old Dominion (14) beats Purdue (3)
# Cincinnati (7) beats Iowa (10)
# Tennessee (2) beats Colgate (15)
#
# Round 2
#
# Virginia (1) beats Ole Miss (8)
# Oregon (12) beats Kansas State (4)
# ...
