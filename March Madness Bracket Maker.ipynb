# %%
from MarchMadness import MarchMadness
import random

# %%
def main():
    march_madness = MarchMadness()
    random.seed()
    march_madness.coin_toss()
    
main()
# Out:
# east :
#
# Round 1
#
# NDS/NCC (16) beats Duke (1)
# UCF (9) beats VCU (8)
# Liberty (12) beats Mississippi St (5)
# Virginia Tech (4) beats Saint Louis (13)
# Belmont (11) beats Maryland (6)
# Yale (14) beats LSU (3)
# Louisville (7) beats Minnesota (10)
# Bradley (15) beats Michigan St (2)
#
# Round 2
#
# NDS/NCC (16) beats UCF (9)
# Liberty (12) beats Virginia Tech (4)
# Belmont (11) beats Yale (14)
# Bradley (15) beats Louisville (7)
#
# Round 3
#
# NDS/NCC (16) beats Liberty (12)
# Bradley (15) beats Belmont (11)
#
# Round 4
#
# NDS/NCC (16) beats Bradley (15)
#
#
#
#
# south :
#
# Round 1
#
# Virginia (1) beats Gardner-Webb (16)
# Ole Miss (8) beats Oklahoma (9)
# Oregon (12) beats Wisconsin (5)
# Kansas State (4) beats UC Irvine (13)
# Villanova (6) beats Saint Mary's (11)
# Purdue (3) beats Old Dominion (14)
# Iowa (10) beats Cincinnati (7)
# Tennessee (2) beats Colgate (15)
#
# Round 2
#
# Ole Miss (8) beats Virginia (1)
# Oregon (12) beats Kansas State (4)
# ...
