# %%
from MarchMadness import MarchMadness
import random

# %%
def main():
    march_madness = MarchMadness()
    random.seed()
    march_madness.coin_toss()
    
main()
# Out:
# east :
#
# Round 1
#
# Duke (1) beats NDS/NCC (16)
# UCF (9) beats VCU (8)
# Liberty (12) beats Mississippi St (5)
# Saint Louis (13) beats Virginia Tech (4)
# Belmont (11) beats Maryland (6)
# LSU (3) beats Yale (14)
# Minnesota (10) beats Louisville (7)
# Bradley (15) beats Michigan St (2)
#
# Round 2
#
# Duke (1) beats UCF (9)
# Saint Louis (13) beats Liberty (12)
# Belmont (11) beats LSU (3)
# Minnesota (10) beats Bradley (15)
#
# Round 3
#
# Saint Louis (13) beats Duke (1)
# Minnesota (10) beats Belmont (11)
#
# Round 4
#
# Saint Louis (13) beats Minnesota (10)
#
#
#
#
# south :
#
# Round 1
#
# Gardner-Webb (16) beats Virginia (1)
# Ole Miss (8) beats Oklahoma (9)
# Wisconsin (5) beats Oregon (12)
# Kansas State (4) beats UC Irvine (13)
# Saint Mary's (11) beats Villanova (6)
# Purdue (3) beats Old Dominion (14)
# Cincinnati (7) beats Iowa (10)
# Tennessee (2) beats Colgate (15)
#
# Round 2
#
# Gardner-Webb (16) beats Ole Miss (8)
# Wisconsin (5) beats Kansas State (4)
# ...
