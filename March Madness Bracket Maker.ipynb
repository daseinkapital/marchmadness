# %%
from MarchMadness import MarchMadness

# %%
def main():
    march_madness = MarchMadness()
    march_madness.coin_toss()
    
main()
# Out:
# east :
#
# Round 1
#
# NDS/NCC (16) beats Duke (1)
# UCF (9) beats VCU (8)
# Liberty (12) beats Mississippi St (5)
# Saint Louis (13) beats Virginia Tech (4)
# Maryland (6) beats Belmont (11)
# Yale (14) beats LSU (3)
# Louisville (7) beats Minnesota (10)
# Bradley (15) beats Michigan St (2)
#
# Round 2
#
# NDS/NCC (16) beats UCF (9)
# Saint Louis (13) beats Liberty (12)
# Maryland (6) beats Yale (14)
# Louisville (7) beats Bradley (15)
#
# Round 3
#
# NDS/NCC (16) beats Saint Louis (13)
# Louisville (7) beats Maryland (6)
#
# Round 4
#
# NDS/NCC (16) beats Louisville (7)
#
#
#
#
# south :
#
# Round 1
#
# Gardner-Webb (16) beats Virginia (1)
# Oklahoma (9) beats Ole Miss (8)
# Oregon (12) beats Wisconsin (5)
# UC Irvine (13) beats Kansas State (4)
# Saint Mary's (11) beats Villanova (6)
# Old Dominion (14) beats Purdue (3)
# Iowa (10) beats Cincinnati (7)
# Tennessee (2) beats Colgate (15)
#
# Round 2
#
# Gardner-Webb (16) beats Oklahoma (9)
# UC Irvine (13) beats Oregon (12)
# ...
