# %%
from MarchMadness import MarchMadness
import random

# %%
march_madness = MarchMadness(MarchMadness.coin_toss)
march_madness.run_bracket()
march_madness.random_championship_score()
# Out:
# east :
#
# Round 1
#
# NDSU (16) beats DUKE (1)
# VCU (8) beats UCF (9)
# LIB (12) beats MSST (5)
# SLU (13) beats VT (4)
# BEL (11) beats MD (6)
# YALE (14) beats LSU (3)
# LOU (7) beats MINN (10)
# BRAD (15) beats MSU (2)
#
# Round 2
#
# NDSU (16) beats VCU (8)
# SLU (13) beats LIB (12)
# YALE (14) beats BEL (11)
# BRAD (15) beats LOU (7)
#
# Round 3
#
# SLU (13) beats NDSU (16)
# YALE (14) beats BRAD (15)
#
# Round 4
#
# SLU (13) beats YALE (14)
#
#
#
#
# west :
#
# Round 1
#
# GONZ (1) beats FDU (16)
# BAY (9) beats SYR (8)
# MURR (12) beats MARQ (5)
# UVM (13) beats FSU (4)
# ASU (11) beats BUFF (6)
# TTU (3) beats NKU (14)
# FLA (10) beats NEV (7)
# MICH (2) beats MONT (15)
#
# Round 2
#
# BAY (9) beats GONZ (1)
# MURR (12) beats UVM (13)
# ASU (11) beats TTU (3)
# MICH (2) beats FLA (10)
#
# Round 3
#
# BAY (9) beats MURR (12)
# ASU (11) beats MICH (2)
#
# Round 4
#
# BAY (9) beats ASU (11)
#
#
#
#
# south :
#
# Round 1
#
# UVA (1) beats WEBB (16)
# MISS (8) beats OKLA (9)
# ...

# %%
march_madness = MarchMadness(MarchMadness.rankings)
march_madness.run_bracket()
march_madness.random_championship_score()
# Out:
# east :
#
# Round 1
#
# DUKE (1) beats NDSU (16)
# VCU (8) beats UCF (9)
# MSST (5) beats LIB (12)
# VT (4) beats SLU (13)
# MD (6) beats BEL (11)
# LSU (3) beats YALE (14)
# LOU (7) beats MINN (10)
# MSU (2) beats BRAD (15)
#
# Round 2
#
# DUKE (1) beats VCU (8)
# VT (4) beats MSST (5)
# LSU (3) beats MD (6)
# MSU (2) beats LOU (7)
#
# Round 3
#
# DUKE (1) beats VT (4)
# MSU (2) beats LSU (3)
#
# Round 4
#
# DUKE (1) beats MSU (2)
#
#
#
#
# west :
#
# Round 1
#
# GONZ (1) beats FDU (16)
# SYR (8) beats BAY (9)
# MARQ (5) beats MURR (12)
# FSU (4) beats UVM (13)
# BUFF (6) beats ASU (11)
# TTU (3) beats NKU (14)
# NEV (7) beats FLA (10)
# MICH (2) beats MONT (15)
#
# Round 2
#
# GONZ (1) beats SYR (8)
# FSU (4) beats MARQ (5)
# TTU (3) beats BUFF (6)
# MICH (2) beats NEV (7)
#
# Round 3
#
# GONZ (1) beats FSU (4)
# MICH (2) beats TTU (3)
#
# Round 4
#
# GONZ (1) beats MICH (2)
#
#
#
#
# south :
#
# Round 1
#
# UVA (1) beats WEBB (16)
# MISS (8) beats OKLA (9)
# WIS (5) beats ORE (12)
# ...

# %%
march_madness = MarchMadness(MarchMadness.weighted_rankings)
march_madness.run_bracket()
march_madness.random_championship_score()
# Out:
# east :
#
# Round 1
#
# 0.9676412215455764
# DUKE (1) beats NDSU (16)
# 0.5225
# UCF (9) beats VCU (8)
# 0.6804309152328266
# MSST (5) beats LIB (12)
# 0.7430475702071273
# VT (4) beats SLU (13)
# 0.6230909688265623
# BEL (11) beats MD (6)
# 0.8114265228554381
# LSU (3) beats YALE (14)
# 0.5705830624999999
# LOU (7) beats MINN (10)
# 0.8860980486212097
# MSU (2) beats BRAD (15)
#
# Round 2
#
# 0.7110503064183037
# DUKE (1) beats UCF (9)
# 0.5225
# VT (4) beats MSST (5)
# 0.7110503064183037
# LSU (3) beats BEL (11)
# 0.6230909688265623
# LOU (7) beats MSU (2)
#
# Round 3
#
# 0.5705830624999999
# VT (4) beats DUKE (1)
# 0.5962593003124999
# LSU (3) beats LOU (7)
#
# Round 4
#
# 0.5225
# VT (4) beats LSU (3)
#
#
#
#
# west :
#
# Round 1
#
# 0.9676412215455764
# GONZ (1) beats FDU (16)
# 0.5225
# BAY (9) beats SYR (8)
# 0.6804309152328266
# MURR (12) beats MARQ (5)
# 0.7430475702071273
# FSU (4) beats UVM (13)
# 0.6230909688265623
# BUFF (6) beats ASU (11)
# 0.8114265228554381
# ...
